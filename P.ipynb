# %%
a=10
b=20
c=30
d=40
e=50
for var in (a,b,c,d,e):
    print(var)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
def st(w):
    return w.startswith("a")

li=['apple','banana','grapes']
res=filter(st,li)
print(list(res))
# Out:
# ['apple']

# %%
x = [1, 2, 3, 4, 5]
squared = map(lambda n: n**2, x)
even_squared = filter(lambda n: n % 2 == 0, squared)
print(list(even_squared))
# Out:
# [4, 16]

# %%
from functools import reduce
# provide an initial value (0) so reduce works even if the iterable is empty/exhausted
result = reduce(lambda x, y: x + y, even_squared, 0)
print(list(result))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2 # provide an initial value (0) so reduce works even if the iterable is empty/exhausted
#       3 result = reduce(lambda x, y: x + y, even_squared, 0)
# ----> 4 print(list(result))
#
# TypeError: 'int' object is not iterable

# %%
num=['1','2','3','4','5']
def number(x):
    res=map(lambda a:a*a,x)
print(list(res))
# Out:
# []

# %%
def twoSum(nums, target):
    seen = {}  # number -> index

    for i, x in enumerate(nums):
        complement = target - x

        if complement in seen:
            return [seen[complement], i]

        seen[x] = i
nums=[2,3,4,5]
target=8
res=twoSum(nums,8)
print(res)
# Out:
# [1, 3]

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
        dummy = ListNode(0)
        cur = dummy
        carry = 0

        while l1 or l2 or carry:
            x = l1.val if l1 else 0
            y = l2.val if l2 else 0

            total = x + y + carry
            carry = total // 10
            digit = total % 10

            cur.next = ListNode(digit)
            cur = cur.next

            l1 = l1.next if l1 else None
            l2 = l2.next if l2 else None

        return dummy.next


# ----------- Helpers for local testing (optional) -----------
def build_list(arr):
    dummy = ListNode(0)
    cur = dummy
    for v in arr:
        cur.next = ListNode(v)
        cur = cur.next
    return dummy.next

def to_array(node):
    out = []
    while node:
        out.append(node.val)
        node = node.next
    return out

# Example test
l1 = build_list([2,4,3])
l2 = build_list([5,6,4])
ans = Solution().addTwoNumbers(l1, l2)
print(to_array(ans))  # [7, 0, 8]
# Out:
# [7, 0, 8]

# %%
list1 = [3, 53, 2, False, 6.2, "Harry"]
for index, item in enumerate(list1):
    print(item, index)
# Out:
# 3 0
# 53 1
# 2 2
# False 3
# 6.2 4
# Harry 5

# %%
list1 = [3, 53, 2, False, 6.2, "harry"]
for i in list1:
    print(i,index)
# Out:
# 3 5
# 53 5
# 2 5
# False 5
# 6.2 5
# harry 5

# %%
def hanoi(n, source, destination, auxiliary):
    if n == 1:
        print(f"Move disk 1 from {source} to {destination}")
        return
    
    # Three recursive calls!
    hanoi(n-1, source, auxiliary, destination)      # Call 1
    print(f"Move disk {n} from {source} to {destination}")
    hanoi(n-1, auxiliary, destination, source)      # Call 2

hanoi(3, 'A', 'C', 'B')
# Out:
# Move disk 1 from A to C
# Move disk 2 from A to B
# Move disk 1 from C to B
# Move disk 3 from A to C
# Move disk 1 from B to A
# Move disk 2 from B to C
# Move disk 1 from A to C

# %%
def factorial(n):
    if n == 0:
        return 1
    # Operation AFTER call
    return n * factorial(n-1)

num=4
print(factorial(num))
# Out:
# 24

# %%
num=[1,]

# %%
Print the first and last character of a string.

Reverse a string using slicing.

Reverse a string using a loop.

Count vowels in a string.

Convert a sentence to title case.

Replace all spaces with hyphens.

Count how many times a letter appears.

Check if two strings are equal.

Check if a string is a palindrome.

Remove leading/trailing spaces.

Split a sentence into words.

Join a list of words into a sentence.

Check if a string contains digits.

Check if all characters are alphabetic.

Check if a string starts with "Py".

Check if a string ends with "ing".

Convert a number to string and print length.

Extract domain name from an email.
(e.g. "hello@gmail.com" → "gmail.com")

Find the index of first occurrence of "o".

Replace all vowels with "*".

Remove all digits from a string.

Extract only digits from a string.

Count words in a sentence.

Remove duplicate characters from a string.

Return initials of a name ("Divya Reddy" → "DR").
# Out:
#   Cell In[30], line 1
#     Print the first and last character of a string.
#           ^
# SyntaxError: invalid syntax

# %%
text="thon programming" 
if text.endswith("ing"):
    print("Found")
else:
    print("Not Found")
# Out:
# Found

# %%
text=input("enter text:")
vowels="aeiouAEIOU"
count=0
for char in text:
    if char in vowels:
        count+=1
print("Number of vowels:",count)
# Out:
# Number of vowels: 0

# %%
for x in [1, 2, 3]:
    

    print(x)   # prints 3
# Out:
# 1
# 2
# 3

# %%
for i in range(int(2.0)):
    print(i)
# Out:
# 0
# 1

# %%
class Student:
    def __init__(a):
        print("Student object created")
s1=Student()
# Out:
# Student object created

# %%
class Car:
    def __init__(self, brand, speed):
        self.brand = brand
        self.speed = speed

    def drive(self):
        return f"{self.brand} is driving at {self.speed} km/h"

car = Car("Toyota", 120)
s = car.drive()
print(s)
# Out:
# Toyota is driving at 120 km/h

# %%
class laptop:
    def __init__(self,brand,price):
        self.brand=brand
        self.price=price
    def dis(self):
        return (f'{self.brand} comes for {self.price}')

# create an instance of laptop
laptop1 = laptop('mac', '1000$')
s = laptop1.dis()
print(s)
# Out:
# mac comes for 1000$

# %%
class laptop:
    def __init__(self,brand,price):
        self.brand=brand
        self.price=price
    def dis(self):
        return (f'{self.brand} comes for {self.price}')

laptop1=laptop('1000','1000$')
s=laptop1.dis()
print(s)
# Out:
# 1000 comes for 1000$

# %%
class bike:
    def __init__(self,brand,price):
        self.brand=brand
        self.price=price
    def dis(self):
        return self.brand,self.price

a=bike('pulsar','10000')
b=a.dis()
print(b)
# Out:
# ('pulsar', '10000')

# %%
def add(*args):
    print(args)

add(1, 2, 3)
# Out:
# (1, 2, 3)

# %%
num=(1,2,3,4,5)
total=0
for i in num:
    total += i
print(total)
# Out:
# 15

# %%
x = 10
print(id(x))
x = x + 1
print(id(x))
# Out:
# 4297386576
# 4297386608

# %%
q = input("welcome to mart (choose q to quit): ")
total = 0
print("fruits\nveggies\nchocs")
while q != "q":
    q = input("welcome to mart (choose q to quit): ")
    if q == "fruits":
        total += 50
    elif q == "veggies":
        total += 30
    elif q == "chocs":
        total += 10
    else:
        print("invalid input")
    print("total:", total)
# Out:
# fruits
# veggies
# chocs
# invalid input
# total: 0
# invalid input
# total: 0
# total: 50
# invalid input
# total: 50
# invalid input
# total: 50
# invalid input
# total: 50
# invalid input
# total: 50

# %%
customer = {"apple": 50, "carrot": 30, "chocolate": 10}
total = 0
while True:
    item = input("Enter item (or 'q' to quit): ")
    if item == "q":
        break
    if item in customer:
        total += customer[item]
    else:
        print("Invalid item")
    print("Total:", total)

# %%
def show_info(**kwargs):
    print(kwargs)

show_info(name="Rahul", age=20)
# Out:
# {'name': 'Rahul', 'age': 20}

# %%
def show(*args, **kwargs):
    # If keyword arguments are provided, print them as a dict
    if kwargs:
        print(kwargs)
    else:
        # Print positional arguments as before
        print(*args)

show(name="Rahul", age=20)
# Out:
# {'name': 'Rahul', 'age': 20}

# %%
def outer():
    def inner():
        return "Inner function"
    return inner

func = outer()
print(func())
# Out:
# Inner function

# %%
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
c=int(input("Enter third number: "))
sum=a+b+c
print("The sum is:",sum)
# Out:
# The sum is: 6

# %%
def make_multiplier(n):

    def multiplier(x):
        return x * n

    return multiplier

double = make_multiplier(2)
print(double(5))
# Out:
# 10

# %%
double = lambda x: x * 2
print(double(2))
# Out:
# 4

# %%
a=10
b+=5
c*=2
print(b)
print(c)
# Out:
# 7
# 4

# %%
feet=int(input("Enter value in feet: "))
meters=feet*0.3048
print("The value in meters is:",meters)
# Out:
# The value in meters is: 0.6096

# %%
num=int(input("Enter a number: "))
if num<100:
    print("The number is less than 100")
else: 
    print("The number is greater than or equal to 100")
# Out:
# The number is less than 100

# %%
num_1=int(input("Enter first number: "))
num_2=int(input("Enter second number: "))
if num_1>num_2:
    print(f"The first number {num_1} is greater than second number{num_2}")
elif num_2>num_1:
    print(f"The second number {num_2} is greater")
else:
    print("Both numbers are equal")
# Out:
# Both numbers are equal

# %%
x, y, z = 1, 2.5, "Hello"
print(x)
print(y)
print(z)
# Out:
# 1
# 2.5
# Hello

# %%
name=input("Enter your name: ")
if 'a' in name:
    print("The letter 'a' is present in your name.")
else:
    print("The letter 'a' is not present in your name.")
# Out:
# The letter 'a' is not present in your name.

# %%
list1 = [1, 2, 3]
list2 = [1, 2, 3]
if list1 is list2:
    print("Both lists point to the same object in memory.")
else:
    print("The lists are different objects in memory.")
# Out:
# The lists are different objects in memory.

# %%
a=25
remainder=a/7
print("The remainder when 25 is divided by 7 is:",remainder)
# Out:
# The remainder when 25 is divided by 7 is: 3.5714285714285716

# %%
def func1():
    print("func1 called")
    return False

# %%
def func2():
    print("func2 called")
    return True

# %%
def left():
    print("left")
    return False

def right():
    print("right")
    return True

result = left() and right()  # prints only "left"; right() never runs
print(result)  # False
# Out:
# left
# False

# %%
num_1=int(input("Enter first number: "))
num_2=int(input("Enter second number: "))
num_3=int(input("Enter third number: "))    
if num_1>=num_2 and num_1>=num_3:
    print(f"The first number {num_1} is the greatest")
elif num_2>=num_1 and num_2>=num_3:
    print(f"The second number {num_2} is the greatest")
else:
    print(f"The third number {num_3} is the greatest")
# Out:
# The first number 2 is the greatest

# %%
str1 = "apple"
str2 = "banana"
if str1 == str2:
    print("Both strings are equal.")
elif str1 < str2:
    print(f'"{str1}" is less than "{str2}".')
else:
    print(f'"{str1}" is greater than "{str2}".')
# Out:
# "apple" is less than "banana".

# %%
num=int(input("Enter first integer: "))
num2=int(input("Enter second integer: "))
if num>0 and num2>0:
    print("Both integers are positive.")
else:
    print("At least one of the integers is not positive.")
# Out:
# Both integers are positive.

# %%
name=input("Enter your name: ")
roll_number=input("Enter your roll number: ")
marks_subject1=float(input("Enter marks in subject 1: "))
marks_subject2=float(input("Enter marks in subject 2: "))
marks_subject3=float(input("Enter marks in subject 3: "))       
total_marks=marks_subject1+marks_subject2+marks_subject3
average_marks=total_marks/3
percentage=(total_marks/300)*100
print(f"Total Marks: {total_marks}")
print(f"Average Marks: {average_marks}")
print(f"Percentage: {percentage}%")
if percentage>=90:
    grade='A'
elif percentage>=80:
    grade='B'
elif percentage>=70:
    grade='C'
elif percentage>=60:
    grade='D'
else:
    grade='F'
print(f"Grade: {grade}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 3
#       1 name=input("Enter your name: ")
#       2 roll_number=input("Enter your roll number: ")
# ----> 3 marks_subject1=float(input("Enter marks in subject 1: "))
#       4 marks_subject2=float(input("Enter marks in subject 2: "))
#       5 marks_subject3=float(input("Enter marks in subject 3: "))
#
# ValueError: could not convert string to float: ''
